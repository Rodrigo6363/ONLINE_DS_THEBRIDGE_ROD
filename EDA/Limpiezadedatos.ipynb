# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # LABORATORY DATA

# %%
path = "./data/Laboratory/"
df_glycoprotein = pd.read_csv(f"{path}AGP_L.csv")
df_HDL= pd.read_csv(f"{path}HDL_L.csv")
df_cholesterol_total = pd.read_csv(f"{path}TCHOL_L.csv")
df_blood_count = pd.read_csv(f"{path}CBC_L.csv")
df_questionary = pd.read_csv(f"{path}FASTQX_L.csv")
df_ferritin = pd.read_csv(f"{path}FERTIN_L.csv")
df_folate = pd.read_csv(f"{path}FOLATE_L.csv")
df_ac_folico =  pd.read_csv(f"{path}FOLFMS_L.csv")
df_glycohemoglobin = pd.read_csv(f"{path}GHB_L.csv")
df_hepatitisA = pd.read_csv(f"{path}HEPA_L.csv")
df_hepatitisB = pd.read_csv(f"{path}HEPB_S_L.csv")
df_reactin_protein = pd.read_csv(f"{path}HSCRP_L.csv")
df_insulin = pd.read_csv(f"{path}INS_L.csv")
df_metals = pd.read_csv(f"{path}PBCD_L.csv")
df_inorganic = pd.read_csv(f"{path}IHGEM_L.csv")
df_serum_folate = pd.read_csv(f"{path}HSCRP_L.csv")
df_hormones = pd.read_csv(f"{path}TST_L.csv")
df_transferrin = pd.read_csv(f"{path}TFR_L.csv")
df_glucose = pd.read_csv(f"{path}GLU_L.csv")
df_urine_pregnancy = pd.read_csv(f"{path}UCPREG_L.csv")
df_vitaminD = pd.read_csv(f"{path}VID_L.csv")
df_demographic = pd.read_csv("./Demographics/DEMO_L.csv")

# %%
# Borro las filas de las que no haya datos de glicoproteína porque no me valen para nada luego para compararlos al peso posterior:
df_glycoprotein = df_glycoprotein.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_glycoprotein = df_glycoprotein[df_glycoprotein['WTPH2YR'] != 0]
df_glycoprotein = df_glycoprotein.drop(['WTPH2YR'], axis=1)
df_glycoprotein.rename(columns={'LBXAGP': 'alpha-1-acid_glycoprotein(g/L)'}, inplace=True)
df_glycoprotein.info()
print("             ")
# Compruebo que no haya duplicados
print(f"Número de filas:{df_glycoprotein.SEQN.nunique()}")
print("             ")
# Distribución de los datos
df_glycoprotein.hist();
df_glycoprotein.to_csv("./data/Data_processed/df_glycoprotein_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1950 entries, 0 to 2563
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   SEQN                            1950 non-null   float64
#  1   alpha-1-acid_glycoprotein(g/L)  1950 non-null   float64
# dtypes: float64(2)
# memory usage: 45.7 KB
#
# Número de filas:1950

# %%
# Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_HDL = df_HDL.dropna()
# Borro la columna de nivel de colesterol pero que no estan las unidades en el sistema internacional
df_HDL = df_HDL.drop(['LBDHDD','WTPH2YR'], axis=1)
df_HDL.rename(columns={'LBDHDDSI': 'HDL-Cholesterol(mmol/L)'}, inplace=True)
# Miro duplicados
df_HDL.info()
print("                     ")
print(f"Número de filas:{df_HDL.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_HDL.hist();
df_HDL.to_csv("./data/Data_processed/df_HDL_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6890 entries, 0 to 8067
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SEQN                     6890 non-null   float64
#  1   HDL-Cholesterol(mmol/L)  6890 non-null   float64
# dtypes: float64(2)
# memory usage: 161.5 KB
#
# Número de filas:6890

# %%
# Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_cholesterol_total = df_cholesterol_total.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_cholesterol_total = df_cholesterol_total[df_cholesterol_total['WTPH2YR'] != 0]
# Borro la columna de nivel de colesterol pero que no estan las unidades en el sistema internacional
df_cholesterol_total = df_cholesterol_total.drop(['WTPH2YR','LBXTC'], axis=1)
df_cholesterol_total.rename(columns={'LBDTCSI': 'Total_Cholesterol(mmol/L)'}, inplace=True)
# Miro duplicados
df_cholesterol_total.info()
print("                     ")
print(f"Número de filas:{df_cholesterol_total.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_cholesterol_total.hist();
df_cholesterol_total.to_csv("./data/Data_processed/df_cholesterol_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6890 entries, 0 to 8067
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEQN                       6890 non-null   float64
#  1   Total_Cholesterol(mmol/L)  6890 non-null   float64
# dtypes: float64(2)
# memory usage: 161.5 KB
#
# Número de filas:6890

# %%
df_blood_count = df_blood_count.dropna()
# Miro duplicados
df_blood_count.info()
print("                     ")
print(f"Número de filas:{df_blood_count.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_blood_count.hist(figsize=(12,12));
df_blood_count.to_csv("./data/Data_processed/df_blood_count_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7582 entries, 0 to 8726
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7582 non-null   float64
#  1   WTPH2YR   7582 non-null   float64
#  2   LBXWBCSI  7582 non-null   float64
#  3   LBXLYPCT  7582 non-null   float64
#  4   LBXMOPCT  7582 non-null   float64
#  5   LBXNEPCT  7582 non-null   float64
#  6   LBXEOPCT  7582 non-null   float64
#  7   LBXBAPCT  7582 non-null   float64
#  8   LBDLYMNO  7582 non-null   float64
#  9   LBDMONO   7582 non-null   float64
#  10  LBDNENO   7582 non-null   float64
#  11  LBDEONO   7582 non-null   float64
#  12  LBDBANO   7582 non-null   float64
#  13  LBXRBCSI  7582 non-null   float64
#  14  LBXHGB    7582 non-null   float64
#  15  LBXHCT    7582 non-null   float64
#  16  LBXMCVSI  7582 non-null   float64
#  17  LBXMC     7582 non-null   float64
#  18  LBXMCHSI  7582 non-null   float64
#  19  LBXRDW    7582 non-null   float64
#  20  LBXPLTSI  7582 non-null   float64
#  21  LBXMPSI   7582 non-null   float64
#  22  LBXNRBC   7582 non-null   float64
# dtypes: float64(23)
# memory usage: 1.4 MB
#
# Número de filas:7582

# %%
# Eliminamos las columnas que tienen gran cantidad de nulos:
df_questionary = df_questionary.drop(['PHACOFHR','PHACOFMN','PHAALCHR','PHAALCMN','PHAGUMHR','PHAGUMMN','PHAANTHR','PHAANTMN','PHASUPHR','PHASUPMN'], axis=1)
# Eliminamos el resto de filas nulas
df_questionary = df_questionary.dropna()
df_questionary.info()
print("                     ")
print(f"Número de filas:{df_questionary.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_questionary.hist(figsize=(12,12));
df_questionary.to_csv("./data/Data_processed/df_questionary_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8631 entries, 0 to 8726
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8631 non-null   float64
#  1   PHQ020    8631 non-null   float64
#  2   PHQ030    8631 non-null   float64
#  3   PHQ040    8631 non-null   float64
#  4   PHQ050    8631 non-null   float64
#  5   PHQ060    8631 non-null   float64
#  6   PHAFSTHR  8631 non-null   float64
#  7   PHAFSTMN  8631 non-null   float64
#  8   PHDSESNZ  8631 non-null   float64
# dtypes: float64(9)
# memory usage: 674.3 KB
#
# Número de filas:8631

# %%
# Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_folate = df_folate.dropna()
# Borro la columna de nivel de colesterol pero que no estan las unidades en el sistema internacional
df_folate = df_folate.drop('LBDRFO', axis=1)
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_folate = df_folate[df_folate['WTPH2YR'] != 0]
# Miro duplicados
df_folate.info()
print("                     ")
print(f"Número de filas:{df_folate.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_folate.hist();
df_folate.to_csv("./data/Data_processed/df_folate_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7506 entries, 0 to 8726
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7506 non-null   float64
#  1   WTPH2YR   7506 non-null   float64
#  2   LBDRFOSI  7506 non-null   float64
# dtypes: float64(3)
# memory usage: 234.6 KB
#
# Número de filas:7506

# %%
# Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_ferritin = df_ferritin.dropna()
# Borro la columna de nivel de ferritina en ng/ml porque en ug/L es mas estandarizado su uso 
df_ferritin = df_ferritin.drop('LBXFER', axis=1)
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_ferritin = df_ferritin[df_ferritin['WTPH2YR'] != 0]
# Miro duplicados
df_ferritin.info()
print("                     ")
print(f"Número de filas:{df_ferritin.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_ferritin.hist();
df_ferritin.to_csv("./data/Data_processed/df_ferritin_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1950 entries, 0 to 2563
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      1950 non-null   float64
#  1   WTPH2YR   1950 non-null   float64
#  2   LBDFERSI  1950 non-null   float64
# dtypes: float64(3)
# memory usage: 60.9 KB
#
# Número de filas:1950

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_ac_folico = df_ac_folico.dropna()
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_ac_folico = df_ac_folico.drop(['LBDFOT'], axis=1)
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_ac_folico = df_ac_folico[df_ac_folico['WTPH2YR'] != 0]
# Miro duplicados
df_ac_folico.info()
print("                     ")
print(f"Número de filas:{df_ac_folico.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_ac_folico.hist(figsize=(12,12));
df_ac_folico.to_csv("./data/Data_processed/df_ac_folico_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7348 entries, 0 to 8726
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7348 non-null   float64
#  1   WTPH2YR   7348 non-null   float64
#  2   LBDFOTSI  7348 non-null   float64
#  3   LBXSF1SI  7348 non-null   float64
#  4   LBDSF1LC  7348 non-null   float64
#  5   LBXSF2SI  7348 non-null   float64
#  6   LBDSF2LC  7348 non-null   float64
#  7   LBXSF3SI  7348 non-null   float64
#  8   LBDSF3LC  7348 non-null   float64
#  9   LBXSF4SI  7348 non-null   float64
#  10  LBDSF4LC  7348 non-null   float64
#  11  LBXSF5SI  7348 non-null   float64
#  12  LBDSF5LC  7348 non-null   float64
#  13  LBXSF6SI  7348 non-null   float64
#  14  LBDSF6LC  7348 non-null   float64
# dtypes: float64(15)
# memory usage: 918.5 KB
#
# Número de filas:7348

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_glycohemoglobin = df_glycohemoglobin.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_glycohemoglobin = df_glycohemoglobin[df_glycohemoglobin['WTPH2YR'] != 0]
df_glycohemoglobin.drop(['WTPH2YR'],axis=1,inplace=True)
# Miro duplicados
df_glycohemoglobin.rename(columns={'LBXGH': 'Glycohemoglobin(%)'}, inplace=True)
df_glycohemoglobin.info()
print("                     ")
print(f"Número de filas:{df_glycohemoglobin.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_glycohemoglobin.hist();
df_glycohemoglobin.to_csv("./data/Data_processed/df_glycohemoglobin_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6715 entries, 0 to 7198
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   SEQN                6715 non-null   float64
#  1   Glycohemoglobin(%)  6715 non-null   float64
# dtypes: float64(2)
# memory usage: 157.4 KB
#
# Número de filas:6715

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_hepatitisA = df_hepatitisA.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_hepatitisA = df_hepatitisA[df_hepatitisA['WTPH2YR'] != 0]
# Miro duplicados
df_hepatitisA.info()
print("                     ")
print(f"Número de filas:{df_hepatitisA.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_hepatitisA.hist();
df_hepatitisA.to_csv("./data/Data_processed/df_hepatitisA_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7366 entries, 0 to 8610
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SEQN     7366 non-null   float64
#  1   WTPH2YR  7366 non-null   float64
#  2   LBXHA    7366 non-null   float64
# dtypes: float64(3)
# memory usage: 230.2 KB
#
# Número de filas:7366

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_hepatitisB = df_hepatitisB.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_hepatitisB = df_hepatitisB[df_hepatitisB['WTPH2YR'] != 0]
# Miro duplicados
df_hepatitisB.info()
print("                     ")
print(f"Número de filas:{df_hepatitisB.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_hepatitisB.hist();
df_hepatitisB.to_csv("./data/Data_processed/df_hepatitisB_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7366 entries, 0 to 8610
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SEQN     7366 non-null   float64
#  1   WTPH2YR  7366 non-null   float64
#  2   LBXHBS   7366 non-null   float64
# dtypes: float64(3)
# memory usage: 230.2 KB
#
# Número de filas:7366

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_reactin_protein = df_reactin_protein.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_reactin_protein = df_reactin_protein[df_reactin_protein['WTPH2YR'] != 0]
df_reactin_protein = df_reactin_protein[df_reactin_protein['LBDHRPLC'] != 1]
df_reactin_protein.drop(['WTPH2YR','LBDHRPLC'],axis=1,inplace=True)
# Miro duplicados
df_reactin_protein.rename(columns={'LBXHSCRP': 'C-Reactive Protein(mg/L)'}, inplace=True)
# Miro duplicados
df_reactin_protein.info()
print("                     ")
print(f"Número de filas:{df_reactin_protein.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_reactin_protein.hist();
df_reactin_protein.to_csv("./data/Data_processed/df_reactin_protein_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7096 entries, 0 to 8726
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEQN                      7096 non-null   float64
#  1   C-Reactive Protein(mg/L)  7096 non-null   float64
# dtypes: float64(2)
# memory usage: 166.3 KB
#
# Número de filas:7096

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_inorganic = df_inorganic.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_inorganic = df_inorganic[df_inorganic['WTPH2YR'] != 0]
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_inorganic = df_inorganic.drop(['LBXIHG','LBXBGE','LBXBGM'], axis=1)
#Miro duplicados
df_inorganic.info()
print("                     ")
print(f"Número de filas:{df_inorganic.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_inorganic.hist(figsize=(10,10));
df_inorganic.to_csv("./data/Data_processed/df_inorganic_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7567 entries, 0 to 8726
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7567 non-null   float64
#  1   WTPH2YR   7567 non-null   float64
#  2   LBDIHGSI  7567 non-null   float64
#  3   LBDIHGLC  7567 non-null   float64
#  4   LBDBGESI  7567 non-null   float64
#  5   LBDBGELC  7567 non-null   float64
#  6   LBDBGMSI  7567 non-null   float64
#  7   LBDBGMLC  7567 non-null   float64
# dtypes: float64(8)
# memory usage: 532.1 KB
#
# Número de filas:7567

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_metals = df_metals.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_metals = df_metals[df_metals['WTPH2YR'] != 0]
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_metals = df_metals.drop(['LBXBPB','LBXBCD','LBXTHG','LBXBSE','LBXBMN'], axis=1)
#Miro duplicados
df_metals.info()
print("                     ")
print(f"Número de filas:{df_metals.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_metals.hist(figsize=(12,12));
df_metals.to_csv("./data/Data_processed/df_metals_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7586 entries, 0 to 8726
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7586 non-null   float64
#  1   WTPH2YR   7586 non-null   float64
#  2   LBDBPBSI  7586 non-null   float64
#  3   LBDBPBLC  7586 non-null   float64
#  4   LBDBCDSI  7586 non-null   float64
#  5   LBDBCDLC  7586 non-null   float64
#  6   LBDTHGSI  7586 non-null   float64
#  7   LBDTHGLC  7586 non-null   float64
#  8   LBDBSESI  7586 non-null   float64
#  9   LBDBSELC  7586 non-null   float64
#  10  LBDBMNSI  7586 non-null   float64
#  11  LBDBMNLC  7586 non-null   float64
# dtypes: float64(12)
# memory usage: 770.5 KB
#
# Número de filas:7586

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_glucose = df_glucose.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_glucose = df_glucose[df_glucose['WTSAF2YR'] != 0]
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso   
df_glucose = df_glucose.drop(['LBXGLU','WTSAF2YR'], axis=1)
df_glucose.rename(columns={'LBDGLUSI': 'Fasting_Glucose(mmol/L))'}, inplace=True)
#Miro duplicados
df_glucose.info()
print("                     ")
print(f"Número de filas:{df_glucose.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_glucose.hist(figsize=(12,12));
df_glucose.to_csv("./data/Data_processed/df_glucose_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3672 entries, 0 to 3995
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEQN                      3672 non-null   float64
#  1   Fasting_Glucose(mmol/L))  3672 non-null   float64
# dtypes: float64(2)
# memory usage: 86.1 KB
#
# Número de filas:3672

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_insulin = df_insulin.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_insulin = df_insulin[df_insulin['WTSAF2YR'] != 0]
df_insulin = df_insulin[df_insulin['LBDINLC'] != 1] # Si es igual a 1 la deteccion fue por debajo del límite
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_insulin = df_insulin.drop(['WTSAF2YR','LBDINLC','LBXIN'], axis=1)
df_insulin.rename(columns={'LBDINSI': 'Insulin(pmol/L)'}, inplace=True)
# #Miro duplicados
df_insulin.info()
print("                     ")
print(f"Número de filas:{df_insulin.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_insulin.hist(figsize=(12,12));
df_insulin.to_csv("./data/Data_processed/df_insulin_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3509 entries, 0 to 3995
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEQN             3509 non-null   float64
#  1   Insulin(pmol/L)  3509 non-null   float64
# dtypes: float64(2)
# memory usage: 82.2 KB
#
# Número de filas:3509

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_hormones = df_hormones.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_hormones = df_hormones[df_hormones['WTPH2YR'] != 0]
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_hormones = df_hormones.drop(['LBX17H','LBXAND','LBXAMH','LBXDHE','LBXEST','LBXESO','LBXES1','LBXPG4','LBXTST'], axis=1)
#Miro duplicados
df_hormones.info()
print("                     ")
print(f"Número de filas:{df_glucose.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_hormones.hist(figsize=(15,15));
df_hormones.to_csv("./data/Data_processed/df_hormones_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6360 entries, 0 to 8492
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      6360 non-null   float64
#  1   WTPH2YR   6360 non-null   float64
#  2   LBD17HSI  6360 non-null   float64
#  3   LBD17HLC  6360 non-null   float64
#  4   LBDANDSI  6360 non-null   float64
#  5   LBDANDLC  6360 non-null   float64
#  6   LBDAMHSI  6360 non-null   float64
#  7   LBDAMHLC  6360 non-null   float64
#  8   LBDDHESI  6360 non-null   float64
#  9   LBDDHELC  6360 non-null   float64
#  10  LBDESTSI  6360 non-null   float64
#  11  LBDESTLC  6360 non-null   float64
#  12  LBDESOSI  6360 non-null   float64
#  13  LBDESOLC  6360 non-null   float64
#  14  LBDES1SI  6360 non-null   float64
#  15  LBDES1LC  6360 non-null   float64
#  16  LBXFSH    6360 non-null   float64
#  17  LBDFSHLC  6360 non-null   float64
#  18  LBXLUH    6360 non-null   float64
#  19  LBDLUHLC  6360 non-null   float64
#  20  LBDPG4SI  6360 non-null   float64
#  21  LBDPG4LC  6360 non-null   float64
#  22  LBXSHBG   6360 non-null   float64
#  23  LBDSHGLC  6360 non-null   float64
#  24  LBDTSTSI  6360 non-null   float64
#  25  LBDTSTLC  6360 non-null   float64
# dtypes: float64(26)
# memory usage: 1.3 MB
#
# Número de filas:3672

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_transferrin = df_transferrin.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_transferrin = df_transferrin[df_transferrin['WTPH2YR'] != 0]
#Borro las columnas que esten en ng/ml porque en nmol/L es mas estandarizado su uso 
df_transferrin = df_transferrin.drop(['LBXTFR'], axis=1)
#Miro duplicados
df_transferrin.info()
print("                     ")
print(f"Número de filas:{df_transferrin.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_transferrin.hist();
df_transferrin.to_csv("./data/Data_processed/df_transferrin_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1949 entries, 0 to 2563
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      1949 non-null   float64
#  1   WTPH2YR   1949 non-null   float64
#  2   LBDTFRSI  1949 non-null   float64
# dtypes: float64(3)
# memory usage: 60.9 KB
#
# Número de filas:1949

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_urine_pregnancy = df_urine_pregnancy.dropna()
#Miro duplicados
df_urine_pregnancy.info()
print("                     ")
print(f"Número de filas:{df_urine_pregnancy.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_urine_pregnancy.hist();
df_urine_pregnancy.to_csv("./data/Data_processed/df_urine_pregnancy_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1130 entries, 0 to 1133
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SEQN     1130 non-null   float64
#  1   URXPREG  1130 non-null   float64
# dtypes: float64(2)
# memory usage: 26.5 KB
#
# Número de filas:1130

# %%
# # Borro las filas de las que no haya datos de colesterol porque no me valen para nada luego para compararlos al peso posterior:
df_vitaminD = df_vitaminD.dropna()
# Si hay un 0 en la columna WTPH2YR significa que el paciente no entrego la muestra de sangre
df_vitaminD = df_vitaminD[df_vitaminD['WTPH2YR'] != 0]
#Miro duplicados
df_vitaminD.info()
print("                     ")
print(f"Número de filas:{df_vitaminD.SEQN.nunique()}")
# Distribución de los datos
print("                     ")
df_vitaminD.hist(figsize=(10,10));
df_vitaminD.to_csv("./data/Data_processed/df_vitaminD_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7238 entries, 0 to 8726
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      7238 non-null   float64
#  1   WTPH2YR   7238 non-null   float64
#  2   LBXVIDMS  7238 non-null   float64
#  3   LBDVIDLC  7238 non-null   float64
#  4   LBXVD2MS  7238 non-null   float64
#  5   LBDVD2LC  7238 non-null   float64
#  6   LBXVD3MS  7238 non-null   float64
#  7   LBDVD3LC  7238 non-null   float64
#  8   LBXVE3MS  7238 non-null   float64
#  9   LBDVE3LC  7238 non-null   float64
# dtypes: float64(10)
# memory usage: 622.0 KB
#
# Número de filas:7238

# %% [markdown]
# # QUESTIONNARIE DATA

# %%
datasheet_questions = pd.read_csv("data/Questions/Datasheet.csv")
datasheet_questions
# Out:
#                            Data File Name      Doc File  \
# 0                              Audiometry     AUQ_L Doc
# 1                           Acculturation     ACQ_L Doc
# 2                             Alcohol Use     ALQ_L Doc
# 3                                 Balance     BAQ_L Doc
# 4            Blood Pressure & Cholesterol     BPQ_L Doc
# 5                   Current Health Status     HSQ_L Doc
# 6                             Dermatology     DEQ_L Doc
# 7                                Diabetes     DIQ_L Doc
# 8               Diet Behavior & Nutrition     DBQ_L Doc
# 9                         Early Childhood     ECQ_L Doc
# 10                            Functioning     FNQ_L Doc
# 11                       Health Insurance     HIQ_L Doc
# 12                              Hepatitis     HEQ_L Doc
# 13  Hospital Utilization & Access to Care     HUQ_L Doc
# 14                Housing Characteristics     HOQ_L Doc
# 15                           Immunization     IMQ_L Doc
# 16                                 Income     INQ_L Doc
# 17            Kidney Conditions - Urology   KIQ_U_L Doc
# 18                     Medical Conditions     MCQ_L Doc
# 19    Mental Health - Depression Screener     DPQ_L Doc
# 20                             Occupation     OCQ_L Doc
# 21                            Oral Health     OHQ_L Doc
# 22                          Pesticide Use  PUQMEC_L Doc
# 23                      Physical Activity     PAQ_L Doc
# 24              Physical Activity - Youth    PAQY_L Doc
# 25               Prescription Medications  RXQ_RX_L Doc
# 26                 Preventive Aspirin Use  RXQASA_L Doc
# 27                    Reproductive Health     RHQ_L Doc
# 28                        Sleep Disorders     SLQ_L Doc
# 29                Smoking - Cigarette Use     SMQ_L Doc
# 30            Smoking - Household Smokers  SMQFAM_L Doc
# 31           Smoking - Recent Tobacco Use  SMQRTU_L Doc
# 32                         Weight History     WHQ_L Doc
#
#                          Data File  Date Published
# 0        AUQ_L Data [XPT - 1.3 MB]  September 2024
# 1      ACQ_L Data [XPT - 445.6 KB]  September 2024
# 2      ALQ_L Data [XPT - 447.6 KB]  September 2024
# 3      BAQ_L Data [XPT - 714.1 KB]    October 2024
# 4      BPQ_L Data [XPT - 400.1 KB]  September 2024
# 5      HSQ_L Data [XPT - 104.4 KB]  September 2024
# 6      DEQ_L Data [XPT - 135.8 KB]  September 2024
# 7      DIQ_L Data [XPT - 827.7 KB]  September 2024
# 8        DBQ_L Data [XPT - 2.5 MB]  September 2024
# 9      ECQ_L Data [XPT - 189.5 KB]  September 2024
# 10       FNQ_L Data [XPT - 2.7 MB]  September 2024
# 11     HIQ_L Data [XPT - 445.2 KB]  September 2024
# 12     HEQ_L Data [XPT - 168.2 KB]  September 2024
# 13     HUQ_L Data [XPT - 269.6 KB]  September 2024
# 14     HOQ_L Data [XPT - 129.2 KB]  September 2024
# 15     IMQ_L Data [XPT - 543.7 KB]  September 2024
# 16     INQ_L Data [XPT - 467.6 KB]  September 2024
# 17   KIQ_U_L Data [XPT - 551.1 KB]  September 2024
# 18       MCQ_L Data [XPT - 3.1 MB]  September 2024
# 19     DPQ_L Data [XPT - 546.9 KB]  September 2024
# 20     OCQ_L Data [XPT - 400.1 KB]  September 2024
# 21     OHQ_L Data [XPT - 334.5 KB]  September 2024
# 22  PUQMEC_L Data [XPT - 190.3 KB]  September 2024
# 23     PAQ_L Data [XPT - 399.9 KB]  September 2024
# 24     PAQY_L Data [XPT - 43.8 KB]  September 2024
# 25  RXQ_RX_L Data [XPT - 280.9 KB]  September 2024
# 26  RXQASA_L Data [XPT - 180.2 KB]  September 2024
# 27     RHQ_L Data [XPT - 400.4 KB]  September 2024
# 28       SLQ_L Data [XPT - 367 KB]  September 2024
# 29     SMQ_L Data [XPT - 635.9 KB]  September 2024
# 30  SMQFAM_L Data [XPT - 280.9 KB]  September 2024
# 31    SMQRTU_L Data [XPT - 1.2 MB]  September 2024
# 32     WHQ_L Data [XPT - 333.5 KB]  September 2024

# %%
# Diccionario para almacenar los DataFrames
dataframes = {}

# Bucle para recorrer cada fila del DataFrame
for index, row in datasheet_questions.iterrows():
    # Eliminar el sufijo ' Doc' si existe y quitar los espacios en 'Doc File'
    doc_file_name = row['Doc File'].replace(' Doc', '').replace(' ', '')  # Elimina ' Doc' y los espacios
    
    # Crear el nombre del DataFrame usando el valor de 'Data File Name', eliminando los espacios y reemplazando guiones por guiones bajos
    df_name = f"df_{row['Data File Name'].replace(' ', '').replace('-', '_')}"  # Elimina espacios y reemplaza '-' por '_'
    
    # Crear la ruta completa para el archivo CSV
    file_path = os.path.join(f"data/Questions/{doc_file_name}.csv")
    
    # Verificar si el archivo existe y leerlo si es así
    if os.path.exists(file_path):
        # Leer el archivo CSV y almacenarlo en el diccionario con el nombre adecuado
        dataframes[df_name] = pd.read_csv(file_path)
        print(f"Archivo {file_path} cargado como {df_name}")
    else:
        print(f"El archivo {file_path} no existe.")

# Ahora puedes acceder a los DataFrames almacenados en el diccionario 'dataframes'
# Ejemplo: acceder al DataFrame de un nombre específico
# Supongamos que tienes un DataFrame llamado 'df_example'
if 'df_example' in dataframes:
    print(dataframes['df_example'].head())  # Muestra las primeras filas de ese DataFrame
# Out:
# Archivo data/Questions/AUQ_L.csv cargado como df_Audiometry
# Archivo data/Questions/ACQ_L.csv cargado como df_Acculturation
# Archivo data/Questions/ALQ_L.csv cargado como df_AlcoholUse
# Archivo data/Questions/BAQ_L.csv cargado como df_Balance
# Archivo data/Questions/BPQ_L.csv cargado como df_BloodPressure&Cholesterol
# Archivo data/Questions/HSQ_L.csv cargado como df_CurrentHealthStatus
# Archivo data/Questions/DEQ_L.csv cargado como df_Dermatology
# Archivo data/Questions/DIQ_L.csv cargado como df_Diabetes
# Archivo data/Questions/DBQ_L.csv cargado como df_DietBehavior&Nutrition
# Archivo data/Questions/ECQ_L.csv cargado como df_EarlyChildhood
# Archivo data/Questions/FNQ_L.csv cargado como df_Functioning
# Archivo data/Questions/HIQ_L.csv cargado como df_HealthInsurance
# Archivo data/Questions/HEQ_L.csv cargado como df_Hepatitis
# Archivo data/Questions/HUQ_L.csv cargado como df_HospitalUtilization&AccesstoCare
# Archivo data/Questions/HOQ_L.csv cargado como df_HousingCharacteristics
# Archivo data/Questions/IMQ_L.csv cargado como df_Immunization
# Archivo data/Questions/INQ_L.csv cargado como df_Income
# Archivo data/Questions/KIQ_U_L.csv cargado como df_KidneyConditions_Urology
# Archivo data/Questions/MCQ_L.csv cargado como df_MedicalConditions
# Archivo data/Questions/DPQ_L.csv cargado como df_MentalHealth_DepressionScreener
# Archivo data/Questions/OCQ_L.csv cargado como df_Occupation
# Archivo data/Questions/OHQ_L.csv cargado como df_OralHealth
# Archivo data/Questions/PUQMEC_L.csv cargado como df_PesticideUse
# Archivo data/Questions/PAQ_L.csv cargado como df_PhysicalActivity
# Archivo data/Questions/PAQY_L.csv cargado como df_PhysicalActivity_Youth
# Archivo data/Questions/RXQ_RX_L.csv cargado como df_PrescriptionMedications
# Archivo data/Questions/RXQASA_L.csv cargado como df_PreventiveAspirinUse
# Archivo data/Questions/RHQ_L.csv cargado como df_ReproductiveHealth
# Archivo data/Questions/SLQ_L.csv cargado como df_SleepDisorders
# Archivo data/Questions/SMQ_L.csv cargado como df_Smoking_CigaretteUse
# Archivo data/Questions/SMQFAM_L.csv cargado como df_Smoking_HouseholdSmokers
# Archivo data/Questions/SMQRTU_L.csv cargado como df_Smoking_RecentTobaccoUse
# Archivo data/Questions/WHQ_L.csv cargado como df_WeightHistory

# %%
df_demographic.drop(["SDDSRVYR","RIDSTATR","RIDAGEMN","RIDEXMON","WTINT2YR","WTMEC2YR","SDMVSTRA","SDMVPSU","RIDRETH1","RIDAGEMN","RIDEXAGM",
"DMDHRAGZ","DMDHRGND","DMDHREDZ","DMDHRMAZ","DMDHSEDZ"],axis=1,inplace=True)

# %%
df_demographic.rename(columns={'RIAGENDR': 'Gender',
                    'RIDAGEYR': 'Age(year)',
                    'RIDRETH3':'Race',
                    'DMQMILIZ':'Served_army',
                    'DMDBORN4':'Country_of_birth',
                    'DMDYRUSR':'Length_time_US',
                    'DMDEDUC2':'Education(adults)',
                    'DMDMARTZ':'Marital_status',
                    'RIDEXPRG':'Pregnancy_status',
                    'DMDHHSIZ':'People_in_Household',
                    'INDFMPIR':'Income_poverty_num'}, inplace=True)

df_demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11933 entries, 0 to 11932
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SEQN                 11933 non-null  float64
#  1   Gender               11933 non-null  float64
#  2   Age(year)            11933 non-null  float64
#  3   Race                 11933 non-null  float64
#  4   Served_army          8301 non-null   float64
#  5   Country_of_birth     11914 non-null  float64
#  6   Length_time_US       1875 non-null   float64
#  7   Education(adults)    7794 non-null   float64
#  8   Marital_status       7792 non-null   float64
#  9   Pregnancy_status     1503 non-null   float64
#  10  People_in_Household  11933 non-null  float64
#  11  Income_poverty_num   9892 non-null   float64
# dtypes: float64(12)
# memory usage: 1.1 MB

# %%
df_demographic['Gender'] = df_demographic['Gender'].replace({1: 'Male', 2: 'Female'})
df_demographic['Race'] = df_demographic['Race'].replace({1: 'Mexican American', 2: 'Other Hispanic',
                                                           3:'Non-Hispanic White',4:'Non-Hispanic Black',
                                                           6:'Non-Hispanic Asian',7:'Other Race'})
df_demographic['Served_army'] = df_demographic['Served_army'].replace({1: 'Yes', 2: 'No',
                                                           7:'Refused',9:'Dont know'})
df_demographic['Country_of_birth'] = df_demographic['Country_of_birth'].replace({1: 'US', 2: 'Others',
                                                           77:'Refused',99:'Dont know'})
df_demographic['Length_time_US'] = df_demographic['Length_time_US'].replace({1: '< 1', 2: '1-4',
                                                           3:'5-9',4:'10-14',
                                                           5:'15-19',6:'>20',
                                                           77:'Refuse',99:'Dont Know'})
df_demographic['Education(adults)'] = df_demographic['Education(adults)'].replace({1: '< 9th grade', 2: '9-11th grade',
                                                           3:'High school',4:'Some college',
                                                           5:'College graduate',
                                                           7:'Refuse',9:'Dont Know'})
df_demographic['Marital_status'] = df_demographic['Marital_status'].replace({1: 'Married/Living with partner', 2: 'Widowed/Divorced/Separated',
                                                           3:'Never married',
                                                           77:'Refuse',99:'Dont Know'})
df_demographic['Pregnancy_status'] = df_demographic['Pregnancy_status'].replace({1: 'Yes', 2: 'No',
                                                           3:'Cannot ascertain',})

# %%
def classify_income(row):
    if row < 2.0:
        return 'Low'
    elif 2.0 <= row < 5.0:
        return 'Middle'
    else:
        return 'High'

# Aplicar la función al DataFrame
df_demographic['Income_poverty'] = df_demographic['Income_poverty_num'].apply(classify_income)

# %%
def simplify_races(row):
    if row == 'Mexican American' or row == 'Other Hispanic' \
        or row == 'Non-Hispanic Black' or row == 'Non-Hispanic Asian'\
            or row =='Other Race':
        return 'Back-Hispanic-Asian'
    else:
        return 'White'

# Aplicar la función al DataFrame
df_demographic['Races_simplify'] = df_demographic['Race'].apply(simplify_races)

# %%
df_demographic.to_csv("./data/Data_processed/df_demographic_clean.csv", index=False)

# %% [markdown]
# # SMOKING

# %%
df_smoking_use = pd.read_csv('data/Questions/SMQ_L.csv')
df_smoking_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9015 entries, 0 to 9014
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9015 non-null   float64
#  1   SMQ020    8135 non-null   float64
#  2   SMQ040    3243 non-null   float64
#  3   SMD641    273 non-null    float64
#  4   SMD650    1185 non-null   float64
#  5   SMD100MN  1175 non-null   float64
#  6   SMQ621    772 non-null    float64
#  7   SMD630    23 non-null     float64
#  8   SMAQUEX2  9015 non-null   float64
# dtypes: float64(9)
# memory usage: 634.0 KB

# %%
df_smoking_use.drop(["SMD641","SMD100MN","SMQ621","SMD630","SMAQUEX2"],axis=1,inplace=True)

# %%
df_smoking_use.rename(columns={'SMQ020': '100_cigarettes_life',
                    'SMQ040': 'now_smoke_cigarettes?',
                    'SMD650':'cigarettes_past_30_days'}, inplace=True)

df_smoking_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9015 entries, 0 to 9014
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   SEQN                     9015 non-null   float64
#  1   100_cigarettes_life      8135 non-null   float64
#  2   now_smoke_cigarettes?    3243 non-null   float64
#  3   cigarettes_past_30_days  1185 non-null   float64
# dtypes: float64(4)
# memory usage: 281.8 KB

# %%
df_smoking_recent_use = pd.read_csv('data/Questions/SMQRTU_L.csv')
df_smoking_recent_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   SEQN     7199 non-null   float64
#  1   SMQ681   6268 non-null   float64
#  2   SMQ690A  792 non-null    float64
#  3   SMQ710   788 non-null    float64
#  4   SMQ720   788 non-null    float64
#  5   SMQ725   784 non-null    float64
#  6   SMQ690B  25 non-null     float64
#  7   SMQ740   25 non-null     float64
#  8   SMQ690C  122 non-null    float64
#  9   SMQ770   122 non-null    float64
#  10  SMQ690G  46 non-null     float64
#  11  SMQ845   46 non-null     float64
#  12  SMQ846   6268 non-null   float64
#  13  SMQ849   400 non-null    float64
#  14  SMQ851   6263 non-null   float64
#  15  SMQ690D  41 non-null     float64
#  16  SMQ690E  8 non-null      float64
#  17  SMQ690K  51 non-null     float64
#  18  SMQ863   5485 non-null   float64
#  19  SMQ690F  86 non-null     float64
#  20  SMDANY   6252 non-null   float64
# dtypes: float64(21)
# memory usage: 1.2 MB

# %%
df_smoking_recent_use.drop(["SMQ690A","SMQ710","SMQ690B","SMQ740","SMQ690C","SMQ770","SMQ690G","SMQ845",
                     "SMQ846","SMQ849","SMQ851","SMQ690D","SMQ690E","SMQ690K","SMQ863","SMQ690F"],axis=1,inplace=True)

df_smoking_recent_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SEQN    7199 non-null   float64
#  1   SMQ681  6268 non-null   float64
#  2   SMQ720  788 non-null    float64
#  3   SMQ725  784 non-null    float64
#  4   SMDANY  6252 non-null   float64
# dtypes: float64(5)
# memory usage: 281.3 KB

# %%
df_smoking_recent_use.rename(columns={'SMQ681':'tobacco_5_days',
                    'SMQ720':'cigarettes_smoked_per_day',
                    'SMQ725':'last_cigarette',
                    'SMDANY':'tobacco_product_5_days?'}, inplace=True)

df_smoking_recent_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEQN                       7199 non-null   float64
#  1   tobacco_5_days             6268 non-null   float64
#  2   cigarettes_smoked_per_day  788 non-null    float64
#  3   last_cigarette             784 non-null    float64
#  4   tobacco_product_5_days?    6252 non-null   float64
# dtypes: float64(5)
# memory usage: 281.3 KB

# %%
df_smoking = pd.merge(df_smoking_use,df_smoking_recent_use,how='inner',on="SEQN")
df_smoking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7199 entries, 0 to 7198
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEQN                       7199 non-null   float64
#  1   100_cigarettes_life        6335 non-null   float64
#  2   now_smoke_cigarettes?      2518 non-null   float64
#  3   cigarettes_past_30_days    922 non-null    float64
#  4   tobacco_5_days             6268 non-null   float64
#  5   cigarettes_smoked_per_day  788 non-null    float64
#  6   last_cigarette             784 non-null    float64
#  7   tobacco_product_5_days?    6252 non-null   float64
# dtypes: float64(8)
# memory usage: 450.1 KB

# %%
df_smoking['100_cigarettes_life'] = df_smoking['100_cigarettes_life'].replace({1: 'Yes', 2: 'No',7:'Refused',9:'Dont know'})
df_smoking['now_smoke_cigarettes?'] = df_smoking['now_smoke_cigarettes?'].replace({1: 'Every day', 2: 'Some days',3:'Not at all',7:'Refused', 9:'Dont know'})
df_smoking['cigarettes_past_30_days'] = df_smoking['cigarettes_past_30_days'].replace({ 777:'Refused',999:'Dont know'})
df_smoking['tobacco_5_days'] = df_smoking['tobacco_5_days'].replace({1: 'Yes', 2: 'No',7:'Refused',9:'Dont know'})
df_smoking['cigarettes_smoked_per_day'] = df_smoking['cigarettes_smoked_per_day'].replace({777:'Refuse',999:'Dont Know'})
df_smoking['last_cigarette'] = df_smoking['last_cigarette'].replace({1: 'Today', 2: 'Yesterday',3:'3 to 5 days ago',7:'Refuse',9:'Dont Know'})
df_smoking['tobacco_product_5_days?'] = df_smoking['tobacco_product_5_days?'].replace({1: 'Yes', 2: 'No', 7:'Refuse',9:'Dont Know'})

df_smoking.to_csv("./data/Data_processed/df_smoking_clean.csv", index=False)

# %% [markdown]
# # WEIGHT HISTORIC

# %%
df_w_pandemic = pd.read_csv("data/Questions/Historic/P_WHQMEC.csv")
df_w_2001 = pd.read_csv("data/Questions/Historic/WHQ_2001_B.csv")
df_w_2003 = pd.read_csv("data/Questions/Historic/WHQ_2003_C.csv")
df_w_2005 = pd.read_csv("data/Questions/Historic/WHQ_2005_D.csv")
df_w_2007 = pd.read_csv("data/Questions/Historic/WHQ_2007_E.csv")
df_w_2009 = pd.read_csv("data/Questions/Historic/WHQ_2009_F.csv")
df_w_2011 = pd.read_csv("data/Questions/Historic/WHQ_2011_G.csv")
df_w_2013 = pd.read_csv("data/Questions/Historic/WHQ_2013_H.csv")
df_w_2015 = pd.read_csv("data/Questions/Historic/WHQ_2015_I.csv")
df_w_2017 = pd.read_csv("data/Questions/Historic/WHQ_2017_J.csv")
df_w_2023 = pd.read_csv("data/Questions/WHQ_L.csv")

list_dataframes = [df_w_pandemic,df_w_2001,df_w_2003,df_w_2005,df_w_2007,df_w_2009,df_w_2011,df_w_2013,df_w_2015,df_w_2017,df_w_2023]

# %%
def clean_weight(df):

    columns = ['SEQN','WHD010','WHD020', 'WHD050', 'WHQ070']

    df = df[columns]

    df = df.dropna()
    df.rename(columns={'WHD010': 'Height(m)',
                    'WHD020': 'Weight(Kg)',
                    'WHD050':'Weight(year_ago)',
                    'WHQ070':'Try_to_loss_weight'},inplace=True)
    
    df['Weight(Kg)'] = df['Weight(Kg)'] * 0.453592
    df['Weight(year_ago)'] = df['Weight(year_ago)'] * 0.453592
    df['Height(m)'] = df['Height(m)'] * 0.0254
    df['IMC'] = np.round(df['Weight(Kg)'] / (df['Height(m)'] ** 2), 1)

    df['IMC_category'] = "Null"


    df.loc[df['IMC'] < 18.5, 'IMC_category'] = "Low weight"
    df.loc[(df['IMC'] >= 18.5) & (df['IMC'] <= 24.9), 'IMC_category'] = "Normal weight"
    df.loc[(df['IMC'] >= 25) & (df['IMC'] <= 29.9), 'IMC_category'] = "Overweight"
    df.loc[(df['IMC'] >= 30) & (df['IMC'] ), 'IMC_category'] = "Obesity"
    
    return df

# %%
# Lista de columnas a verificar
required_columns = ['WHD010', 'WHD020', 'WHD050', 'WHQ070']

# Bucle para comprobar si las columnas están en todos los DataFrames de la lista
for i, df in enumerate(list_dataframes):
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        print(f"DataFrame {i} is missing columns: {missing_columns}")
    else:print(f"DataFrame {i} has all the required columns.")
# Out:
# DataFrame 0 has all the required columns.
# DataFrame 1 has all the required columns.
# DataFrame 2 has all the required columns.
# DataFrame 3 has all the required columns.
# DataFrame 4 has all the required columns.
# DataFrame 5 has all the required columns.
# DataFrame 6 has all the required columns.
# DataFrame 7 has all the required columns.
# DataFrame 8 has all the required columns.
# DataFrame 9 has all the required columns.
# DataFrame 10 has all the required columns.

# %%
df_w_pandemic = clean_weight(df_w_pandemic)
df_w_2001 =clean_weight(df_w_2001)
df_w_2003 = clean_weight(df_w_2003)
df_w_2005 = clean_weight(df_w_2005)
df_w_2007 = clean_weight(df_w_2007)
df_w_2009 = clean_weight(df_w_2009)
df_w_2011 = clean_weight(df_w_2011)
df_w_2013 = clean_weight(df_w_2013)
df_w_2015 = clean_weight(df_w_2015)
df_w_2017 = clean_weight(df_w_2017)
df_w_2023 = clean_weight(df_w_2023)

df_w_pandemic.to_csv("./data/Data_processed/df_w_pandemic.csv", index=False)
df_w_2001.to_csv("./data/Data_processed/df_w_2001.csv", index=False)
df_w_2003.to_csv("./data/Data_processed/df_w_2003.csv", index=False)
df_w_2005.to_csv("./data/Data_processed/df_w_2005.csv", index=False)
df_w_2007.to_csv("./data/Data_processed/df_w_2007.csv", index=False)
df_w_2009.to_csv("./data/Data_processed/df_w_2009.csv", index=False)
df_w_2011.to_csv("./data/Data_processed/df_w_2011.csv", index=False)
df_w_2013.to_csv("./data/Data_processed/df_w_2013.csv", index=False)
df_w_2015.to_csv("./data/Data_processed/df_w_2015.csv", index=False)
df_w_2017.to_csv("./data/Data_processed/df_w_2017.csv", index=False)
df_w_2023.to_csv("./data/Data_processed/df_w_2023.csv", index=False)

# %%
all_dates = ["pandemic", "2001", "2003", "2005", "2007", "2009", "2011", "2013", "2015", "2017","2023"]
list_dataframes = [df_w_pandemic,df_w_2001,df_w_2003,df_w_2005,df_w_2007,df_w_2009,df_w_2011,df_w_2013,df_w_2015,df_w_2017,df_w_2023]

for i, df in enumerate(list_dataframes):
    df['Year'] = all_dates[i]

# %%
df_weigth_historic = pd.concat(list_dataframes, axis=0)

df_weigth_historic

df_weigth_historic.to_csv("./data/Data_processed/df_weigth_historic.csv", index=False)

# %% [markdown]
# ### CHOLESTEROL TOTAL

# %%
df_cholesterol_final= pd.merge(df_cholesterol_total, df_HDL, on="SEQN", how="inner")
df_cholesterol_final.info()
df_cholesterol_final["Cholesterol_index"] = df_cholesterol_final["Total_Cholesterol(mmol/L)"] / df_cholesterol_final["HDL-Cholesterol(mmol/L)"]
df_cholesterol_final
df_cholesterol_obesidad = pd.merge(df_cholesterol_final, df_w_2023, on="SEQN", how="inner")
df_cholesterol_obesidad.info()
df_cholesterol_obesidad.IMC_category.unique()
df_cholesterol_obesidad.to_csv("./data/Data_processed/df_cholesterol_imc_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6890 entries, 0 to 6889
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEQN                       6890 non-null   float64
#  1   Total_Cholesterol(mmol/L)  6890 non-null   float64
#  2   HDL-Cholesterol(mmol/L)    6890 non-null   float64
# dtypes: float64(3)
# memory usage: 161.6 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5946 entries, 0 to 5945
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SEQN                       5946 non-null   float64
#  1   Total_Cholesterol(mmol/L)  5946 non-null   float64
#  2   HDL-Cholesterol(mmol/L)    5946 non-null   float64
#  3   Cholesterol_index          5946 non-null   float64
#  4   Height(m)                  5946 non-null   float64
#  5   Weight(Kg)                 5946 non-null   float64
#  6   Weight(year_ago)           5946 non-null   float64
#  7   Try_to_loss_weight         5946 non-null   float64
#  8   IMC                        5946 non-null   float64
#  9   IMC_category               5946 non-null   object
#  10  Year                       5946 non-null   object
# dtypes: float64(9), object(2)
# memory usage: 511.1+ KB

# %% [markdown]
# # DIABETES

# %%
df_temp = pd.merge(df_insulin, df_glucose, on="SEQN", how="inner")
df_diabetes = pd.merge(df_temp, df_glycohemoglobin, on="SEQN", how="inner")
df_diabetes_pob = pd.merge(df_w_2023, df_diabetes, on="SEQN", how="inner")
df_diabetes_pob.info()
df_diabetes_pob.to_csv("./data/Data_processed/df_diabetes_clean.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3266 entries, 0 to 3265
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SEQN                      3266 non-null   float64
#  1   Height(m)                 3266 non-null   float64
#  2   Weight(Kg)                3266 non-null   float64
#  3   Weight(year_ago)          3266 non-null   float64
#  4   Try_to_loss_weight        3266 non-null   float64
#  5   IMC                       3266 non-null   float64
#  6   IMC_category              3266 non-null   object
#  7   Year                      3266 non-null   object
#  8   Insulin(pmol/L)           3266 non-null   float64
#  9   Fasting_Glucose(mmol/L))  3266 non-null   float64
#  10  Glycohemoglobin(%)        3266 non-null   float64
# dtypes: float64(9), object(2)
# memory usage: 280.8+ KB
